# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/ifood_df.csv')

# %%
df1 = pd.read_csv('/content/walmart-sales-dataset-of-45stores.csv')

# %%
df
# Out:
#       Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0      58138        0         0       58       635         88
# 1      46344        1         1       38        11          1
# 2      71613        0         0       26       426         49
# 3      26646        1         0       26        11          4
# 4      58293        1         0       94       173         43
# ...      ...      ...       ...      ...       ...        ...
# 2200   61223        0         1       46       709         43
# 2201   64014        2         1       56       406          0
# 2202   56981        0         0       91       908         48
# 2203   69245        0         1        8       428         30
# 2204   52869        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 0                 546              172                88            88
# 1                   6                2                 1             6
# ...

# %%
df.shape
# Out:
# (2205, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   int64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                        count          mean           std     min      25%  \
# Income                2205.0  51622.094785  20713.063826  1730.0  35196.0
# Kidhome               2205.0      0.442177      0.537132     0.0      0.0
# Teenhome              2205.0      0.506576      0.544380     0.0      0.0
# Recency               2205.0     49.009070     28.932111     0.0     24.0
# MntWines              2205.0    306.164626    337.493839     0.0     24.0
# MntFruits             2205.0     26.403175     39.784484     0.0      2.0
# MntMeatProducts       2205.0    165.312018    217.784507     0.0     16.0
# MntFishProducts       2205.0     37.756463     54.824635     0.0      3.0
# MntSweetProducts      2205.0     27.128345     41.130468     0.0      1.0
# MntGoldProds          2205.0     44.057143     51.736211     0.0      9.0
# NumDealsPurchases     2205.0      2.318367      1.886107     0.0      1.0
# NumWebPurchases       2205.0      4.100680      2.737424     0.0      2.0
# ...

# %% [markdown]
# Data Cleaning

# %%
df.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
df.duplicated().sum()
# Out:
# 184

# %%
df[df.duplicated()]
# Out:
#       Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 77     38620        0         0       56       112         17
# 167    78497        0         0       44       207         26
# 267    51369        0         1       84       297          7
# 268    37760        0         0       20        84          5
# 346    37717        1         0       31         9          0
# ...      ...      ...       ...      ...       ...        ...
# 2185   22775        1         0       40         5          1
# 2188   75777        0         0       12       712         26
# 2192   58554        1         1       55       368         24
# 2199   34421        1         0       81         3          3
# 2201   64014        2         1       56       406          0
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# 77                 44               34                22            89
# 167               447               75                 0           223
# ...

# %%
df['Kidhome'] = df['Kidhome'].astype('category')
df['Teenhome'] = df['Teenhome'].astype('category')
df['AcceptedCmp1'] = df['AcceptedCmp1'].astype('category')
df['AcceptedCmp2'] = df['AcceptedCmp2'].astype('category')
df['AcceptedCmp3'] = df['AcceptedCmp3'].astype('category')
df['AcceptedCmp4'] = df['AcceptedCmp4'].astype('category')
df['AcceptedCmp5'] = df['AcceptedCmp5'].astype('category')
df['Complain'] = df['Complain'].astype('category')
df['marital_Divorced'] = df['marital_Divorced'].astype('category')
df['marital_Married'] = df['marital_Married'].astype('category')
df['marital_Single'] = df['marital_Single'].astype('category')
df['marital_Together'] = df['marital_Together'].astype('category')
df['marital_Widow'] = df['marital_Widow'].astype('category')
df['education_2n Cycle'] = df['education_2n Cycle'].astype('category')
df['education_Basic'] = df['education_Basic'].astype('category')
df['education_Graduation'] = df['education_Graduation'].astype('category')
df['education_Master'] = df['education_Master'].astype('category')
df['education_PhD'] = df['education_PhD'].astype('category')

# %% [markdown]
# # **Exploratory data analysis**

# %%
df["Age"].mean()
# Out:
# 51.09569160997732

# %%
sns.histplot(df["Age"])
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
df["Income"].mean()
# Out:
# 51622.0947845805

# %%
sns.histplot(df["Income"])
plt.title("Income Distribution")
plt.xlabel("Income")
plt.ylabel("Count")
plt.show()

# %%
k = df["marital_Married"].value_counts()
v = k.reset_index()
v
# Out:
#   marital_Married  count
# 0               0   1351
# 1               1    854

# %%
plt.bar(v["marital_Married"], v["count"])
plt.title("Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Count")
plt.show()

# %%
df.corr()
# Out:
#                         Income   Kidhome  Teenhome   Recency  MntWines  \
# Income                1.000000 -0.531699  0.042483  0.006716  0.730495
# Kidhome              -0.531699  1.000000 -0.040207  0.011829 -0.499288
# Teenhome              0.042483 -0.040207  1.000000  0.013881  0.002783
# Recency               0.006716  0.011829  0.013881  1.000000  0.016470
# MntWines              0.730495 -0.499288  0.002783  0.016470  1.000000
# MntFruits             0.537920 -0.374388 -0.176925 -0.004909  0.384947
# MntMeatProducts       0.702500 -0.445665 -0.267177  0.026138  0.593119
# MntFishProducts       0.551758 -0.389895 -0.206371  0.001177  0.395967
# MntSweetProducts      0.555601 -0.379101 -0.164246  0.025535  0.388613
# MntGoldProds          0.417653 -0.356550 -0.019619  0.018558  0.390194
# NumDealsPurchases    -0.132427  0.226434  0.394341  0.000479  0.011858
# NumWebPurchases       0.503184 -0.375590  0.161229 -0.005104  0.552342
# ...

# %%
df.drop(columns=["Z_CostContact","Z_Revenue"],inplace = True)

# %%
df.corr()
# Out:
#                         Income   Kidhome  Teenhome   Recency  MntWines  \
# Income                1.000000 -0.531699  0.042483  0.006716  0.730495
# Kidhome              -0.531699  1.000000 -0.040207  0.011829 -0.499288
# Teenhome              0.042483 -0.040207  1.000000  0.013881  0.002783
# Recency               0.006716  0.011829  0.013881  1.000000  0.016470
# MntWines              0.730495 -0.499288  0.002783  0.016470  1.000000
# MntFruits             0.537920 -0.374388 -0.176925 -0.004909  0.384947
# MntMeatProducts       0.702500 -0.445665 -0.267177  0.026138  0.593119
# MntFishProducts       0.551758 -0.389895 -0.206371  0.001177  0.395967
# MntSweetProducts      0.555601 -0.379101 -0.164246  0.025535  0.388613
# MntGoldProds          0.417653 -0.356550 -0.019619  0.018558  0.390194
# NumDealsPurchases    -0.132427  0.226434  0.394341  0.000479  0.011858
# NumWebPurchases       0.503184 -0.375590  0.161229 -0.005104  0.552342
# ...

# %%
plt.figure(figsize=(20,14))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
# Separate numerical and categorical variables
numerical_vars = df.select_dtypes(include=['int64', 'float64']).columns
categorical_vars = df.select_dtypes(include=['category']).columns


numerical_stats = df[numerical_vars].describe()


categorical_stats = df[categorical_vars].describe()

numerical_stats
# Out:
#               Income      Recency     MntWines    MntFruits  MntMeatProducts  \
# count    2205.000000  2205.000000  2205.000000  2205.000000      2205.000000
# mean    51622.094785    49.009070   306.164626    26.403175       165.312018
# std     20713.063826    28.932111   337.493839    39.784484       217.784507
# min      1730.000000     0.000000     0.000000     0.000000         0.000000
# 25%     35196.000000    24.000000    24.000000     2.000000        16.000000
# 50%     51287.000000    49.000000   178.000000     8.000000        68.000000
# 75%     68281.000000    74.000000   507.000000    33.000000       232.000000
# max    113734.000000    99.000000  1493.000000   199.000000      1725.000000
#
#        MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# count      2205.000000       2205.000000   2205.000000        2205.000000
# mean         37.756463         27.128345     44.057143           2.318367
# ...

# %%
categorical_stats
# Out:
#         Kidhome  Teenhome  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# count      2205      2205          2205          2205          2205
# unique        3         3             2             2             2
# top           0         0             0             0             0
# freq       1276      1139          2042          2041          2044
#
#         AcceptedCmp1  AcceptedCmp2  Complain  marital_Divorced  \
# count           2205          2205      2205              2205
# unique             2             2         2                 2
# top                0             0         0                 0
# freq            2063          2175      2185              1975
#
#         marital_Married  marital_Single  marital_Together  marital_Widow  \
# count              2205            2205              2205           2205
# unique                2               2                 2              2
# top                   0               0                 0              0
# ...

# %%
corr_matrix_numerical = df[numerical_vars].corr()

plt.figure(figsize=(14,12))
sns.heatmap(corr_matrix_numerical, annot=True, cmap='viridis', linewidths=0.5)
plt.title(' Matrix for Numerical Variables')
plt.show()

# %%
corr_matrix_cat = df[categorical_vars].corr()

plt.figure(figsize=(14,12))
sns.heatmap(corr_matrix_cat, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap for Numerical Variables')
plt.show()

# %%
# For numerical variables
for col in numerical_vars:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=False)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# For categorical variables
for col in categorical_vars:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=df[col])
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
df["AcceptedCmp4"].value_counts()
# Out:
# 5112

# %% [markdown]
# **Conculsion**
#
# Our campaign is profitable.
#
# A major segment of our customers have children, so we should focus on kid products as well to increase our sales.
#
# We need to put more focus on offline stores and establish more offline outlets.
#
# People show interest in discounted products.

# %%
df
# Out:
#       Income Kidhome Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0      58138       0        0       58       635         88              546
# 1      46344       1        1       38        11          1                6
# 2      71613       0        0       26       426         49              127
# 3      26646       1        0       26        11          4               20
# 4      58293       1        0       94       173         43              118
# ...      ...     ...      ...      ...       ...        ...              ...
# 2200   61223       0        1       46       709         43              182
# 2201   64014       2        1       56       406          0               30
# 2202   56981       0        0       91       908         48              217
# 2203   69245       0        1        8       428         30              214
# 2204   52869       1        1       40        84          3               61
#
# ...
